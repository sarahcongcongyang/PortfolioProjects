# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv('/kaggle/input/movies/movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
# checking for missing values
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}% missing'.format(col, pct_missing))
# Out:
# name - 0.0% missing
# rating - 0.010041731872717789% missing
# genre - 0.0% missing
# year - 0.0% missing
# released - 0.0002608242044861763% missing
# score - 0.0003912363067292645% missing
# votes - 0.0003912363067292645% missing
# director - 0.0% missing
# writer - 0.0003912363067292645% missing
# star - 0.00013041210224308815% missing
# country - 0.0003912363067292645% missing
# budget - 0.2831246739697444% missing
# gross - 0.02464788732394366% missing
# company - 0.002217005738132499% missing
# runtime - 0.0005216484089723526% missing

# %%
# drop the missing value 
df = df.dropna()
df.shape
# Out:
# (5421, 15)

# %%
# data types for the columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data typle of the columns
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# creat correct year column
df['yearcorrect'] = df['year'].astype(str).str[:4]
df['yearcorrect'].equals(['year'])
# Out:
# False

# %%
#df

# %%
# sort data by 'gross' descending
df = df.sort_values(by = 'gross', inplace = False, ascending = False)
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# show all the data in the df
#pd.set_option('display.max_rows',None)

# %%
# drop duplicates
#df['company'].drop_duplicates().sort_values(ascending = False)
df = df.drop_duplicates()
df.shape
# Out:
# (5421, 16)

# %%
# checking the correlation
# scatterplot budget vs. gross
plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Earnng')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')
plt.show()

# %%
# plot budget vs gross using seaborn
sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {"color":"red"}, line_kws = {"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# checking for the correlation
correlation_matrix = df.corr(method = 'pearson',numeric_only = True) #kendall, spearman
correlation_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# change object data to category codes
df_cat = df
for col in df_cat.columns:
    if (df_cat[col].dtype == 'object'):
        df_cat[col] = df_cat[col].astype('category').cat.codes
df_cat
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
cor_code_matrix = df_cat.corr(method = 'pearson')
sns.heatmap(cor_code_matrix, annot = True)
# Out:
# <Axes: >

# %%
corr_pairs = cor_code_matrix.unstack()
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# genre        gross         -0.244101
# gross        genre         -0.244101
# budget       rating        -0.203946
#                               ...
# gross        gross          1.000000
# director     director       1.000000
# yearcorrect  yearcorrect    1.000000
#              year           1.000000
# year         yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr_pairs = sorted_pairs[(sorted_pairs) > 0.4]
high_corr_pairs
# Out:
# score        runtime        0.414068
# runtime      score          0.414068
# votes        budget         0.439675
# budget       votes          0.439675
# score        votes          0.474256
# votes        score          0.474256
# gross        votes          0.614751
# votes        gross          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# name         name           1.000000
# company      company        1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# votes        votes          1.000000
# writer       writer         1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# director     director       1.000000
# ...

# %%
# votes and budget have the highest correlation with gross
# gross        votes          0.614751
# gross        budget         0.740247
